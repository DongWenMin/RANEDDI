# %%
# %tensorflow_version 1.4.0

# %%
import os
from google.colab import drive
drive.mount('/DWM')
path = "/DWM/My Drive/UPLOAD/RANEDDI_binary_DDI_prediction_model/Model"
os.chdir(path)
os.listdir(path)
# Out:
# Mounted at /DWM
# ['__pycache__', 'utility', '.vscode', 'RANEDDI_main.py', 'RANEDDI.py']

# %%
! python RANEDDI_main.py
# Out:
# [n_drugs]=[1710]
# [n_train, n_test]=[345380, 38376]
# [batch_size, batch_size_kg]=[1024, 300]
# /DWM/My Drive/UPLOAD/RANEDDI_binary_DDI_prediction_model/Model/utility/loader_raneddi.py:136: RuntimeWarning: divide by zero encountered in power
#   d_inv = np.power(rowsum, -1).flatten()
# 	generate si-normalized adjacency matrix.
# 	reordering indices...
# 	reorganize all kg data done.
# 	sort meta-data done.
# 	sort all data done.
# 检索test，train数据完毕。
# WARNING:tensorflow:From RANEDDI_main.py:19: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:From /DWM/My Drive/UPLOAD/RANEDDI_binary_DDI_prediction_model/Model/RANEDDI.py:306: The name tf.sparse_reorder is deprecated. Please use tf.sparse.reorder instead.
#
# WARNING:tensorflow:From /DWM/My Drive/UPLOAD/RANEDDI_binary_DDI_prediction_model/Model/RANEDDI.py:59: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:
# ...

# %%
! python RANEDDI_main.py
