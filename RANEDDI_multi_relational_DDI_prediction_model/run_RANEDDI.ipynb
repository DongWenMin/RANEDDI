# %%
# %tensorflow_version 1.4.0
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.4.0`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
import os
from google.colab import drive
drive.mount('/DWM')
path = "/DWM/My Drive/UPLOAD/RANEDDI_multi_relational_DDI_prediction_model/Model"
os.chdir(path)
os.listdir(path)
# Out:
# Drive already mounted at /DWM; to attempt to forcibly remount, call drive.mount("/DWM", force_remount=True).
# ['README.md',
#  'RANEDDI_main.py',
#  'RANEDDI.py',
#  'output',
#  '__pycache__',
#  '.vscode',
#  'utility']

# %%
# !python RANEDDI_main.py
# Out:
# [n_drug]=[1710]
# [n_train, n_test]=[345380, 38376]
# [n_entities, n_relations]=[1710, 1]
# [batch_size]=[1024]
# /DWM/My Drive/UPLOAD/RANEDDI_multi_relational_DDI_prediction_model/Model/utility/loader_raneddi.py:81: RuntimeWarning: divide by zero encountered in power
#   d_inv = np.power(rowsum, -1).flatten()
# 	generate si-normalized adjacency matrix.
# 	reordering indices...
# 	reorganize all kg data done.
# 	sort meta-data done.
# 	sort all data done.
# 检索test，train数据完毕。
# WARNING:tensorflow:From RANEDDI_main.py:16: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:From /DWM/My Drive/UPLOAD/RANEDDI_multi_relational_DDI_prediction_model/Model/RANEDDI.py:73: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
# ...
